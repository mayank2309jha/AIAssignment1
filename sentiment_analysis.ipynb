# %%
from textblob import TextBlob

# %%
one = "The food at Radison was awesome"
two = "The food at Radison was very good"
blob1 = TextBlob(one)
blob2 = TextBlob(two)
print(blob1.sentiment)
print(blob2.sentiment)
# Out:
# Sentiment(polarity=1.0, subjectivity=1.0)
# Sentiment(polarity=0.9099999999999999, subjectivity=0.7800000000000001)

# %%
import pandas as pd
df = pd.read_csv("knowledge_base.csv")

def get_sentiment(text):
    analysis = TextBlob(text)
    return analysis.sentiment.polarity

df['Sentiment'] = df['Feedback'].apply(get_sentiment)

sorted_df = df.sort_values(by='Sentiment', ascending=False)

sorted_df
# Out:
#                                Location       Region  \
# 569                  Gole Market, Delhi        India
# 302  Abu Dhabi Corniche, Abu Dhabi, UAE  Middle East
# 397                      Gdansk, Poland       Europe
# 496   Sahara Desert, Multiple Countries       Africa
# 497      Seychelles Beaches, Seychelles       Africa
# ..                                  ...          ...
# 75                    Auli, Uttarakhand        India
# 79     Rishikonda Beach, Andhra Pradesh        India
# 504       Chobe National Park, Botswana       Africa
# 80                Varkala Beach, Kerala        India
# 170      Huanglong Scenic Area, Sichuan        China
#
#                                Weather    Rating  \
# 569     Mild,Summer,Not Cloudy,No rain  8.000000
# 302     Mild, Summer, Not Cloudy, Rain  9.271834
# 397     Mild, Summer, Not Cloudy, Rain  7.860590
# 496  Mild, Summer, Not Cloudy, No Rain  9.058129
# 497         Mild, Summer, Cloudy, Rain  7.694333
# ..                                 ...       ...
# 75       Extreme, Summer, Cloudy, Rain  7.619097
# 79       Extreme, Summer, Cloudy, Rain  7.470248
# 504      Mild, Summer, Cloudy, No Rain  6.498473
# 80       Extreme, Summer, Cloudy, Rain  5.210734
# 170  Mild, Winter, Not Cloudy, No Rain  5.822596
#
#                                           Connectivity  \
# 569                         Good. Close metro station.
# 302                                   close to airport
# 397                                   close to airport
# 496                                   close to airport
# 497                                   close to airport
# ..                                                 ...
# 75   Remote location with poor cellular reception, ...
# 79   Remote location with poor cellular reception, ...
# 504  Remote location with poor cellular reception, ...
# 80   Remote location with poor cellular reception, ...
# 170  Remote location with poor cellular reception, ...
#
#                                               Feedback  \
# 569  Nice place. Nice shops nearby. Very good place...
# 302  Airport proximity for swift escapes. Breezy st...
# 397  Airport proximity for swift escapes. Breezy st...
# 496  Airport proximity for swift escapes. Breezy st...
# 497  Airport proximity for swift escapes. Breezy st...
# ..                                                 ...
# 75   Remote location, poor reception complicate nav...
# 79   Remote location, poor reception complicate nav...
# 504  Remote location, poor reception complicate nav...
# 80   Remote location, poor reception complicate nav...
# 170  Remote location, poor reception complicate nav...
#
#                                             Activities  Sentiment
# 569                  ['Walking', 'Running', 'Cycling']      0.702
# 302  [['Adventure sports (e.g., zip-lining, paragli...      0.600
# 397  [['Relaxing at beaches', 'Cruises or boat tour...      0.600
# 496  [['Exploring local markets', 'Taking cooking c...      0.600
# 497  [['Taking cooking classes', 'Attending cultura...      0.600
# ..                                                 ...        ...
# 75   [['Joining city walks or food tours', 'Photogr...     -0.250
# 79   [['Visiting museums', 'Golfing', 'Water sports...     -0.250
# 504  [['Visiting amusement parks', 'Visiting religi...     -0.250
# 80   [['Relaxing at beaches', 'Water sports (e.g., ...     -0.250
# 170  [['Visiting religious or spiritual sites', 'Re...     -0.250
#
# [570 rows x 8 columns]
